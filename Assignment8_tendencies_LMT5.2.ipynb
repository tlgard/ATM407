# %% [markdown]
# <a name="top"></a>
#
# <div style="width:1000 px">
#
# <div style="float:right; width:300 px"><img src="https://github.com/brianmapes/ATM407/blob/master/images/LMT_5.4.png?raw=true" alt="Heating tendencies LMT_5.4 exercise image" style="height: 200px;"></div>
#
#
# <h1>Assignment 8: Heating rates in a midlatitude cyclone</h1>
# <h3>ATM 407, University of Miami</h3>
#
# * To use these Jupyter notebooks, you need to have installed all this:
# https://brianmapes.github.io/EarthCube-DRILSDOWN/ )
#
#
# ### Activities
# 1. <a href="#Exercise1">Some math about it</a>
# 1. <a href="#Exercise2">Load an IDV bundle</a>
# 1. <a href="#Exercise3">Answer the book's LMT_5.4 questions</a>
# 1. <a href="#Exercise4">Use LMT_5.4_MERRA_1979-2015 to make the same bundle for YOUR case.</a>
# 1. <a href="#Exercise5">Answer the mose interesting part for YOUR case.</a>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">

# %% [markdown]
# ### Background
# Remember, for the test you will memorize and write the primitive equations:
# 1. Horizontal acceleration equation (F=ma):
# $$ \frac{d}{dt} \vec V_h = f \vec V_h \times \hat k  - \vec \nabla_p \Phi +\vec F_r  $$
# or, in component form,
# $$ \frac{du}{dt} = fv  - \frac{\partial \Phi}{\partial x} +F_{rx} $$
# $$ \frac{dv}{dt} = -fu - \frac{\partial \Phi}{\partial y} +F_{ry} $$
#
# 1. Vertical acceleration equation (aka Hydrostatic balance):
# $$ \frac {\partial \Phi}{\partial p} = - \alpha \equiv -\frac{1}{\rho} = \frac{RT}{p} = \frac{R\theta}{p} (\frac{T}{\theta})$$
# 1. Mass continuity:
# $$ 0 = \frac {\partial u}{\partial x} + \frac {\partial v}{\partial y}  + \frac {\partial \omega}{\partial p} $$
# 1. First Law of thermodynamics:
# $$ \frac {d \theta}{dt} = Q_\theta $$
# where $Q_\theta$, the heating rate in $\theta$ units, is related to dT/dt_{diabatic} = Q (in W/kg units) by:
# $$ Q_\theta = Q/C_p\frac{\theta}{T} $$
#
#
# #### For this exercise, let's focus on the First Law in the form used by atmosphere models (Eulerian grids).
#
# $$ \frac {\partial \theta}{\partial t} = -V \cdot \nabla \theta + Q_\theta  = Q_{dyn} + Q_{phys}$$
#
# Or, more to the point for digital atmospheric models with a finite timestep dt,
#
# $$ \theta_{future}(x,y,p) = \theta_{present} + dt \frac{(Q_{dyn} + Q_{phys} )} {C_p} \frac{\theta}{T}$$
#
# Save room in your brain for the concept of $Q_{ana}$, the *analysis tendency*, which is *the tendency required to make a model evolve in time as the world was observed to evolve in time.* (That is, *the sum of all errors in model estimates of Q{phys} and Q_{dyn} from all its derivatives and combinations of its state variables).
#
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise1"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 1</b>:
#      <ul>
#
# <li>**What is $\frac{\theta}{T}$ in the above casting of the equations? ** Show that it involves only the coordinate variable $p$.</li>
#
# <li>We can express $Q$ into the 3 physical forms of heat transfer (from fundamental physics): *radiation, conduction, convection, and chemical reaction.*</li>
#
# $$Q_{phys} = Q_{rad} +  Q_{surface} + Q_{turb} + Q_{chem}$$
#
# <li>**Explain in words how these map onto the column heating physics in atmosphere model:**</li>
#
# $$Q_{phys} = Q_{LW} +  Q_{SW} + Q_{SHF} + Q_{PBL \ diffusion} +Q_{gridscale \ cond-evap} + Q_{subgrid \ cumulus \ convection} +Q_{frictional \ dissipation}$$
#
# <li>**Explain how the profile of longwave radiation $Q_{LW}$ relates to the profile of cloudiness.**</li>
#
#     </ul>
# </div>

# %% [markdown]
# ## Exercise 1 Answer:
# ### First question bullet:
#
# $\frac{\theta}{T}$ =
#
#
# ### Second question (third bullet):
# 1. Q_LW is purely **radiative** (LW="longwave", the infrared radiation emitted by parts of the Earth system).
# 2. Q_SW is shortwave radiation, the solar radiation emitted by the sun.
# 3. Q_SHF is is surface flux.
# 4. Q_PBL is purely **turbulent** (heat transfer from one altitude to another carried by small or "subgrid" parcels of air).
# 5. Q_cond is condensation.
# 6. Q_cumulus is a mix of watervapor and latent heat release.
# 7. Q_friction is arguably a version of **"conduction"**, as the kinetic energy of the wind gets turned into heat by the **physical contact** of molecules from micro-airmasses with different velocities.
#
# ### Third question (fourth bullet):
#
# Longwave heaing Q_LW is positive where more infrared photons arrive than leave. It is negative wherever more IR photons leave than arrive. Cloud effects can be understood using the concept that solid surfaces (both the Earth and cloud top and bottom) absorb all photons that strike them (no reflection), and emit more or less according to their local temperature as $\sigma T^4$. Since temperature T decreases with height in the troposphere, ... (complete the paragraph logically) ...

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise2"></a>
# ## Exercise 2: Find and load the LMT_5.4 bundle. Capture the storm image.

# %% [markdown]
# <div class="alert alert-info">
#     <b>Note</b>:
#      (If you like, you could do the Sandy version I made yesterday as a test, but it is bigger and slower to load.)
# </div>

# %%
# %reload_ext drilsdown
# Out:
# A Jupyter Widget
# Loading extensions from ~/.ipython/extensions is deprecated. We recommend managing extensions like any other Python packages, in site-packages.

# %%
# Your image 
# %makeImage
# Out:
# tempfile.tempdir = None
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise3"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 3</b>:
#      <ul>
#       <li>**Answer the LMT_5.4 questions a-k, using image captures and Markdown cells to make this notebook a readable document you are proud of.**
#
#       </li>
#
#        <li>To do this, **copy the boldface question for each part from the text**, and then write your answers in normal text, so that a reader of this notebook gets a coherent narrative.
#
#       </li>
#
#     </ul>
# </div>

# %%
# %makeImage -caption example
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %% [markdown]
# ## Markdown answer for a):
#
#
# **a) What is the blah of the blah?**
#
# The model's rainfall estimate are pretty well represented from the satellite observations. I see no discrepancies, so the storm is very well analyzed in the model. From this, I would argue that the analysis is a very good representation of the storm.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption example
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %%
# %makeMovie
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %% [markdown]
# ## Markdown answer for b):
#
#
# Once Again, the precipitation total graphics match up very well with the column-integrated physical heating rate. The interesting change we see in this graphic is that in the 1500 UTC frame, the majority of the land to the west of the system has a negative heating rate while the area to the east has a positive heating rate. In the 1800 UTC frame, all areas have a positive heating rate.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeMovie
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %% [markdown]
# ## Markdown answer for c):
#
# Negative dynamical advective tendency would show cold advection, upward vertical motion, which covers the area of precipitation. In the second frame of the area, it shows that cold air is being advected to the southeast. There is also an area of this negative advection right behind the front that is acting as fuel to reinforce it.  This doesn't line up with the MERRA pretcot.
# The adiabatic cooling balances out the relaease of latent heat from condensation.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeMovie
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %% [markdown]
# ## Markdown answer for d):
#
# The column of integrated tendencies has some correspondence with MERRA's prectot. The area directly around the low shows negative tendencies, which is in line with part c above. However, the tail of the storm that becomes the long front does not until the second frame. This pattern is followed similarly by the advective tendency. I would argue that the troph is deepening slightly and propogating eastward

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeMovie
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %%
# %makeMovie
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %% [markdown]
# ## Markdown answer for e):
#
#
# I am not sure, but I would think the magnitude of the field is pretty small/

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %%
# %makeImage -caption example
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %% [markdown]
# ## Markdown answer for f):
#
#
# The low clouds are located at the very center of the low. Higher clouds will be just outside the edge of the low and to the east where much of the air is rising. Middle level clouds are located more towards the left of the storm.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption example
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %% [markdown]
# ## Markdown answer for g):
#
# The first image shows the longwave radiative heating rate. It shows the majority of the positive heating rate takes place at the bases of very high clouds, as well as some at the surface. This is becasue the upwards source of radiation is stronger that the downwards source.
# The majority of cloud top to space is cooling due to a net loss in radiation. I would estimate its value to be at -0.864 K/s.
#
# The second image is the shortwave radiative heating rate due to absorption of sunlight. This image shows their to be a net positive heating rate. Compared to dtdtrad (net heating rate). I would say that the longwave is closer to the net.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption example
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %% [markdown]
# ## Markdown answer for h):
#
#
# The turbulent and frictional heating terms are both active exclusively at the surface. Frional by land only causes effects near the surface, and turbulence only effects the boundary layer cause there's not friction aloft. Their max magnitudes are near 5E-5.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption example
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %% [markdown]
# ## Markdown answer for i):
#
#
# The area to the left of the low but still within the cloud layer and the densely packed area to the right of the center are saturated with moist heating. There is an absense of a large magnitude at the center where there are only low clouds. Also, to the east and west of the clouds there is none. It is negative to the downstream of the tallest clouds, which tells me this may be where the outflow is located.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption example
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %% [markdown]
# ## Markdown answer for j):
#
#
# The total of all moisture processes dtdttot shows a large amount of moist heating and postivie radative rate throughout the column of air that emcompasses the high clouds, to the right of the storm. The same can be said for the area just to the left of the center, but at a smaller magnitude. It also shows the positive magnitudes for the surface, brought on by turbulant processes.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption example
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %%
# %makeImage
# Out:
# tempfile.tempdir = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'
# tempfile.gettempdir() = '/var/folders/yw/hb5js5dn5pdg3g9lgyskr6sr0000gn/T'

# %% [markdown]
# ## Markdown answer for k):
#
#
# The heat budget hear appears to be primarily adiabatic. You can tell that the column is mainly contributed by the lower tropsophere, as the column integrated tendencies match up very similarly to the dynamical tendencys

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise4"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 4</b>:
#      <ul>
#           <li>**Choose a storm case of your own. ** Maybe you did this last week. Choose carefully: you will revisit this as a project and perhaps make a Wikipedia page about it. If you like, choose a new one at this point.
#       </li>
#
#       <li>**Do the second optional exercise (loading LMT_5.4_MERRA_1979-2015 and moving the time and space box) for your case.**
#
#        <li>**Capture an image comparable to your favorite subsection above.**
#
#       </li>
#     </ul>
# </div>

# %%
# To use this feature, the IDV display must have its ID set to this name, in Properties. 
# %makeImage
# Out:
# ERROR:root:Line magic function `%makeImage` not found.

# %% [markdown]
# ## My case:
#
# #### I decided to study a storm that occurred (date and time, place), because (background info).
#
# The image above shows ...

# %%
# Wikipedia image
from IPython.display import Image
Image("an image URL goes here")

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# Upload your image to your GitHub area and put its URL into Blackboard.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">
